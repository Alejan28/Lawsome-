# %% [markdown]
# # Installing dependencies

# %%
# !pip install -q -U transformers accelerate faker bitsandbytes
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 37.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.4/59.4 MB 19.7 MB/s eta 0:00:00

# %% [markdown]
# # Uploading model

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
from faker import Faker
import json
import re
from datetime import datetime, timedelta

MODEL_ID = "OpenLLM-Ro/RoLlama3-8b-Instruct-DPO-2025-04-23"

print(f"Se încarcă modelul {MODEL_ID} în mod 4-bit")

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.float16
)

try:
    tokenizer = AutoTokenizer.from_pretrained(MODEL_ID)
    tokenizer.pad_token = tokenizer.eos_token

    model = AutoModelForCausalLM.from_pretrained(
        MODEL_ID,
        quantization_config=bnb_config,
        device_map="auto", # Asta merge perfect pe GPU NVIDIA
        trust_remote_code=True
    )
    print("Model încărcat cu succes pe GPU!")
except Exception as e:
    print(f"Eroare încărcare: {e}")
# Out:
# Se încarcă modelul OpenLLM-Ro/RoLlama3-8b-Instruct-DPO-2025-04-23 în mod 4-bit
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/512 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/765 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.17G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/194 [00:00<?, ?B/s]
# Model încărcat cu succes pe GPU!

# %% [markdown]
# # Template procura

# %%
def get_template_procura(meta):
  text = f"""PROCURĂ SPECIALĂ

Subsemnatul {meta['mandant']['nume']}, cetățean român, domiciliat în {meta['mandant']['adresa']}, identificat cu C.I {meta['c.i.']}, C.N.P. {meta['mandant']['cnp']},
împuternicesc prin prezenta pe {meta['mandatar']['nume']}, cetățean român, domiciliat în {meta['mandatar']['adresa']}, C.N.P. {meta['mandatar']['cnp']},

Ca în numele meu şi pentru mine să se prezinte şi să mă reprezinte, cu puteri depline în vederea îndeplinirii tuturor formalităţilor necesare:
{meta['scop']}.

Eu, {meta['mandant']['nume']}, declar că am citit personal întregul cuprins al acestuia, i-am înţeles conţinutul şi consecinţele juridice, solicitând autentificarea prezentului înscris.

Mandatul este netransmisibil şi valabil până la data de {meta['termen']}.

Tehnoredactată la BIROU NOTARIAL PUBLIC, într-un exemplar original și 3 duplicate.

Mandant,
{meta['mandant']['nume']}
"""
  return text

# %% [markdown]
# # Template metadata

# %%
fake = Faker('ro_RO')
def genereaza_metadata():
    scopuri = [
        "vânzarea apartamentului nr. 10, bloc A3, din București",
        "reprezentarea la succesiune și partaj voluntar",
        "înmatricularea autoturismului și reprezentarea la RAR",
        "ridicarea pensiei și administrarea conturilor bancare"
    ]
    return {
        "mandant": {"nume": fake.name(), "cnp": fake.ssn(), "adresa": fake.address().replace("\n", ", ")},
        "mandatar": {"nume": fake.name(), "cnp": fake.ssn(), "adresa": fake.address().replace("\n", ", ")},
        "scop": random.choice(scopuri),
        "termen": (datetime.now() + timedelta(days=365)).strftime("%d.%m.%Y"),
        "c.i.": fake.ssn()
    }

# %%
from faker import Faker
import random
from datetime import datetime, timedelta

fake = Faker('ro_RO')

def genereaza_date_complete():
    # Definim o listă extinsă de scenarii realiste din practica notarială
    scenarii = [
        # --- SCENARIUL 1: CĂLĂTORIE MINOR (DECLARAȚIE) ---
        {
            "tip_act": "DECLARAȚIE ACORD CĂLĂTORIE",
            "scop": "ieșire din țară minor neînsoțit de ambii părinți",
            "extra": {
                "minor": {"nume": fake.name(), "data_nasterii": "20.05.2016"},
                "insotitor": {"nume": fake.name(), "cnp": fake.ssn()}, # Poate fi bunic, mătușă etc.
                "destinatie": random.choice(["Grecia", "Turcia", "Spania", "Italia", "Marea Britanie"]),
                "perioada": "01.08.2025 - 20.08.2025",
                "motiv": "turism și vacanță"
            }
        },

        # --- SCENARIUL 2: AUTO (ÎNMATRICULARE) ---
        {
            "tip_act": "PROCURĂ SPECIALĂ AUTO",
            "scop": "reprezentare RAR și DRPCIV pentru înmatriculare",
            "extra": {
                "auto": {
                    "marca": random.choice(["Dacia Duster", "Ford Focus", "Volkswagen Golf", "Toyota Corolla"]),
                    "serie_sasiu": "".join(random.choices("ABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789", k=17)),
                    "an_fabricatie": str(random.randint(2010, 2024))
                }
            }
        },

        # --- SCENARIUL 3: IMOBILIARE (VÂNZARE) ---
        {
            "tip_act": "PROCURĂ SPECIALĂ IMOBILIARĂ",
            "scop": "vânzare apartament",
            "extra": {
                "imobil": {
                    "tip": "apartament 2 camere",
                    "adresa": fake.address().replace("\n", ", "),
                    "nr_carte_funciara": str(random.randint(10000, 99999)),
                    "pret_minim": f"{random.randint(60, 150)}000 EURO"
                }
            }
        },

        # --- SCENARIUL 4: IMOBILIARE (CUMPĂRARE) ---
        {
            "tip_act": "PROCURĂ DE CUMPĂRARE",
            "scop": "achiziție imobil și semnare contract credit ipotecar",
            "extra": {
                "buget_maxim": f"{random.randint(80, 200)}000 EURO",
                "zona_preferata": "București sau Ilfov",
                "banca": random.choice(["Banca Transilvania", "BCR", "BRD", "ING Bank"])
            }
        },

        # --- SCENARIUL 5: SUCCESIUNE (MOȘTENIRE) ---
        {
            "tip_act": "PROCURĂ SUCCESORALĂ",
            "scop": "reprezentare la dezbaterea succesiunii",
            "extra": {
                "defunct": {"nume": fake.name(), "data_deces": (datetime.now() - timedelta(days=random.randint(10, 100))).strftime("%d.%m.%Y")},
                "notar_competent": "oricare notar public din raza Municipiului București",
                "optiune": "acceptarea pură și simplă a succesiunii"
            }
        },

        # --- SCENARIUL 6: CORPORATE (FIRMĂ) ---
        {
            "tip_act": "PROCURĂ SPECIALĂ ONRC",
            "scop": "înființare societate comercială (SRL)",
            "extra": {
                "nume_firma": f"{fake.word().upper()} SOLUTIONS SRL",
                "capital_social": "200 RON",
                "sediu_social": fake.address().replace("\n", ", ")
            }
        },

        # --- SCENARIUL 7: BANCAR (CONTURI) ---
        {
            "tip_act": "PROCURĂ BANCARĂ",
            "scop": "administrare conturi și ridicare carduri",
            "extra": {
                "banca": random.choice(["Raiffeisen Bank", "UniCredit", "CEC Bank"]),
                "operatiuni_permise": "depuneri, retrageri numerar, lichidare depozite, ridicare extrase de cont"
            }
        },

        # --- SCENARIUL 8: PENSIE/DREPTURI BĂNEȘTI ---
        {
            "tip_act": "PROCURĂ RIDICARE PENSIE",
            "scop": "ridicarea pensiei lunare și a taloanelor",
            "extra": {
                "institutie": "Casa Județeană de Pensii",
                "oficiu_postal": "Oficiul Poștal din raza de domiciliu",
                "valabilitate": "până la revocare dar nu mai mult de 3 ani"
            }
        },

        # --- SCENARIUL 9: FISCAL (ANAF) ---
        {
            "tip_act": "PROCURĂ REPREZENTARE FISCALĂ",
            "scop": "obținere certificat atestare fiscală și depunere declarații",
            "extra": {
                "institutie": "Direcția Taxe și Impozite Locale și ANAF",
                "motiv": "vânzare imobil și regularizare taxe"
            }
        },

        # --- SCENARIUL 10: ADMINISTRATIV (ACTE STARE CIVILĂ) ---
        {
            "tip_act": "PROCURĂ SPECIALĂ",
            "scop": "obținere duplicat certificat de naștere/căsătorie",
            "extra": {
                "act_cerut": random.choice(["Certificat de Naștere", "Certificat de Căsătorie", "Cazier Judiciar"]),
                "autoritate": "Serviciul de Stare Civilă / Poliția Română"
            }
        }
    ]

    # Alegem un scenariu aleatoriu
    scenariu = random.choice(scenarii)

    # Construim obiectul metadata final
    meta = {
        "tip_act": scenariu["tip_act"],
        "scop": scenariu["scop"],
        "mandant": {
            "nume": fake.name(),
            "cnp": fake.ssn(),
            "adresa": fake.address().replace("\n", ", ")
        },
        "mandatar": {
            "nume": fake.name(),
            "cnp": fake.ssn(),
            "adresa": fake.address().replace("\n", ", ")
        },
        "data_semnarii": datetime.now().strftime("%d.%m.%Y"),
        # Adăugăm datele extra direct în rădăcină pentru ca LLM-ul să le vadă ușor
        **scenariu["extra"]
    }

    return meta

# %% [markdown]
# # Generator

# %%
def generator(meta):
    exemplu_text = get_template_procura(meta)

    prompt = f"""
SARCINĂ: Redactează textul final pentru o procură notarială.
Folosește structura și limbajul juridic din textul de mai jos, modificând detaliile minore dacă este necesar pentru coerență.

TEXT SURSĂ:
{exemplu_text}

INSTRUCȚIUNE: Returnează textul complet al procurii.
"""
    return run_llm([{"role": "user", "content": prompt}], max_new=900)

# %%
import json
import re

def genereaza_scenariu_llm():
    """
    Folosește LLM-ul pentru a inventa un scenariu notarial complex și a-l returna ca JSON.
    """

    prompt = """
Ești un Generator de Date Sintetice pentru domeniul juridic.
SARCINA TA: Inventează un scenariu realist pentru un act notarial (procură sau declarație).
Fii creativ! Variază tipul actului (imobiliar, auto, succesiune, divorț, firmă, declarație călătorie).

TREBUIE SĂ RĂSPUNZI DOAR CU UN JSON VALID.
Respectă cu strictețe această structură (schema):

{
    "tip_act": "Tipul documentului (ex: PROCURĂ SPECIALĂ IMOBILIARĂ)",
    "scop": "Descrierea scurtă a mandatului",
    "mandant": {
        "nume": "Nume complet (inventat)",
        "cnp": "CNP valid (inventat)",
        "adresa": "Adresa completă (inventată)"
    },
    "mandatar": {
        "nume": "Nume complet (inventat)",
        "cnp": "CNP valid (inventat)",
        "adresa": "Adresa completă (inventată)"
    },
    "detalii_extra": {
        "descriere": "Orice detaliu specific necesar (ex: marca mașinii, adresa imobilului, numele minorului, numele băncii etc.)"
    }
}

REGULI:
1. Inventeaza scenarii plauzibile si logice.
2. Inventează date plauzibile (serii șasiu, numere cadastrale).
3. Nu scrie nimic înainte sau după JSON.
4. Nu te repeta.
"""

    # Folosim o temperatură mai mare (0.85) pentru creativitate și diversitate
    raw_res = run_llm([{"role": "user", "content": prompt}], max_new=600, temp=0.85)

    # Parser robust pentru JSON
    try:
        # Curățăm markdown-ul (```json ... ```)
        clean_res = raw_res.replace("```json", "").replace("```", "").strip()

        # Găsim acoladele
        start = clean_res.find("{")
        end = clean_res.rfind("}") + 1

        if start != -1:
            json_obj = json.loads(clean_res[start:end])

            # Asigurăm compatibilitatea cu scriptul de generare documente
            # (Mutăm detaliile extra în rădăcină, ca să fie ușor accesibile)
            if "detalii_extra" in json_obj:
                extra = json_obj.pop("detalii_extra")
                json_obj.update(extra)

            return json_obj

    except Exception as e:
        print(f" Eroare generare scenariu JSON: {e}")
        print(f"   Raw output: {raw_res[:100]}...")

    # Fallback: Dacă LLM-ul greșește JSON-ul, returnăm un scenariu default ca să nu crăpe
    return {
        "tip_act": "PROCURĂ GENERALĂ",
        "scop": "administrare bunuri",
        "mandant": {"nume": "Fallback User", "cnp": "1800101000000", "adresa": "București"},
        "mandatar": {"nume": "Fallback Agent", "cnp": "1800101000000", "adresa": "București"}
    }

# %%
def run_llm(messages, max_new=512, temp=0.7):
    # Pregătire input
    input_ids = tokenizer.apply_chat_template(
        messages, add_generation_prompt=True, return_tensors="pt"
    ).to(model.device)

    attention_mask = torch.ones_like(input_ids)

    outputs = model.generate(
        input_ids,
        attention_mask=attention_mask,
        max_new_tokens=max_new,
        do_sample=True,
        temperature=temp,
        pad_token_id=tokenizer.eos_token_id,
        eos_token_id=tokenizer.eos_token_id
    )

    response = outputs[0][input_ids.shape[-1]:]
    return tokenizer.decode(response, skip_special_tokens=True)

# %% [markdown]
# # Critic

# %%
def critic(text, meta):
    """
    Verifică într-un singur pas atât structura (Forma) cât și conținutul (Scopul).
    """
    scop_cerut = meta.get('scop', 'Nespecificat')
    mandant_cerut = meta['mandant']['nume']

    prompt = f"""
Ești un AUDITOR NOTARIAL EXPERT.
Analizează documentul de mai jos și completează raportul de validare JSON.

DATE DE REFERINȚĂ (Ce trebuie să conțină):
1. Scopul Mandatului: "{scop_cerut}"
2. Mandant: "{mandant_cerut}"

TEXT DE VERIFICAT:
---
{text[:2000]}
--- (text trunchiat pentru analiză)

SARCINĂ DE AUDIT:
A. VERIFICARE FORMĂ:
   - Textul pare complet (are titlu, final)?
   - S-au eliminat toate placeholder-ele gen "...", "___", "[Data]"? (CRITIC!)
   - Există numele mandantului?

B. VERIFICARE SCOP:
   - Textul menționează clar acțiunea cerută ("{scop_cerut}")? (Atenție la sinonime juridice).

RĂSPUNDE DOAR CU ACEST JSON STRICT:
{{
    "forma_ok": (bool - false dacă există "..." sau lipsesc părți),
    "scop_ok": (bool - true dacă scopul e acoperit),
    "scor_calitate": (int 1-10),
    "observatii": "scurtă explicație a erorilor sau OK"
}}
"""
    # Temperatură mică pentru rigoare
    raw_res = run_llm([{"role": "user", "content": prompt}], max_new=300, temp=0.2)

    print(f"   [RAȚIONAMENT CRITIC]: {raw_res}") # Debug

    try:
        # Curățare JSON (metoda robustă)
        clean_res = raw_res.replace("```json", "").replace("```", "").strip()
        start = clean_res.find("{")
        end = clean_res.rfind("}") + 1

        if start != -1:
            return json.loads(clean_res[start:end])
        return None
    except:
        return None

# %% [markdown]
# # Cleaning up the data

# %%
import os
import glob
from google.colab import drive

if not os.path.exists('/content/drive'):
    drive.mount('/content/drive')
else:
    print("Google Drive este deja conectat.")

# Folderul sursă specificat de tine
folder_input = "/content/drive/MyDrive/Colab Notebooks/procura"

# Folderul unde salvăm datele curate (creăm un subfolder ca să fie ordine)
folder_output = "/content/drive/MyDrive/Colab Notebooks/procura_cleaned"

# Creăm folderul de output dacă nu există
if not os.path.exists(folder_output):
    os.makedirs(folder_output)
    print(f"Am creat folderul pentru rezultate: {folder_output}")


def curata_document_cu_llm(text_murdar):
    """
    Trimite textul cu '...' la LLM și îi cere să îl completeze coerent.
    """
    prompt = f"""
SARCINĂ: Ești un asistent juridic expert.
Ai primit un document ciornă care conține spații libere marcate cu "..." sau puncte.
Rescrie textul completând TOATE spațiile libere cu DATE FICTIVE, dar plauzibile pentru context (nume, date, CNP-uri, adrese).

REGULI:
1. Elimină absolut toate "..." și înlocuiește-le cu date concrete.
2. Nu folosi paranteze pătrate [Nume] în textul final, ci pune direct un nume (ex: Popescu Ion).
3. Păstrează structura juridică intactă.
4. Returnează DOAR textul curățat.

TEXT ORIGINAL:
{text_murdar}
"""
    # Apelăm modelul (presupunem că run_llm e deja definită în celulele anterioare)
    return run_llm([{"role": "user", "content": prompt}], max_new=1024, temp=0.4)

fisiere_gasite = glob.glob(f"{folder_input}/*.txt")

print(f"\nCaut în: {folder_input}")
print(f"Am găsit {len(fisiere_gasite)} fișiere text (.txt).")

if len(fisiere_gasite) == 0:
    print("ATENȚIE: Nu am găsit niciun fișier .txt în acest folder!")
    print("Asigură-te că modelele tale sunt salvate ca Text Document (.txt) în Drive.")
else:
    print("Încep procesarea...\n")

    for i, cale_fisier in enumerate(fisiere_gasite):
        nume_fisier = os.path.basename(cale_fisier)
        print(f"[{i+1}/{len(fisiere_gasite)}] Procesez: {nume_fisier}...")

        try:
            # Citire
            with open(cale_fisier, 'r', encoding='utf-8') as f:
                text_brut = f.read()

            # Curățare cu AI
            text_curat = curata_document_cu_llm(text_brut)

            # Salvare pe Drive
            cale_salvare = os.path.join(folder_output, f"CURAT_{nume_fisier}")
            with open(cale_salvare, 'w', encoding='utf-8') as f:
                f.write(text_curat)

            print(f"  Salvat: Dataset_Procuri_Curate/CURAT_{nume_fisier}")

        except Exception as e:
            print(f" Eroare: {e}")

    print(f"\n Gata! Toate documentele curățate sunt în: {folder_output}")
# Out:
# Google Drive este deja conectat.
# Am creat folderul pentru rezultate: /content/drive/MyDrive/Colab Notebooks/procura_cleaned
#
# Caut în: /content/drive/MyDrive/Colab Notebooks/procura
# Am găsit 27 fișiere text (.txt).
# Încep procesarea...
#
# [1/27] Procesez: procura-auto-pentru-imprumutul-masinii-in-tara-sau-strainatate.txt...
#   Salvat: Dataset_Procuri_Curate/CURAT_procura-auto-pentru-imprumutul-masinii-in-tara-sau-strainatate.txt
# [2/27] Procesez: procura-cumparare-imobil-pret-fix-151-lei-acte-si-modele-incluse-1.txt...
#   Salvat: Dataset_Procuri_Curate/CURAT_procura-cumparare-imobil-pret-fix-151-lei-acte-si-modele-incluse-1.txt
# [3/27] Procesez: procura-cazier-judiciar.txt...
#   Salvat: Dataset_Procuri_Curate/CURAT_procura-cazier-judiciar.txt
# [4/27] Procesez: procura-vanzare-apartament-acte-necesare-cost-si-model.txt...
#   Salvat: Dataset_Procuri_Curate/CURAT_procura-vanzare-apartament-acte-necesare-cost-si-model.txt
# [5/27] Procesez: procura-obtinere-nif.txt...
#   Salvat: Dataset_Procuri_Curate/CURAT_procura-obtinere-nif.txt
# [6/27] Procesez: procura-pentru-copil-minor.txt...
#   Salvat: Dataset_Procuri_Curate/CURAT_procura-pentru-copil-minor.txt
# [7/27] Procesez: procura-inmatriculare-auto-2025-model-pret-si-acte.txt...
#   Salvat: Dataset_Procuri_Curate/CURAT_procura-inmatriculare-auto-2025-model-pret-si-acte.txt
# [8/27] Procesez: procura-generala-de-administrare-imobil-apartament-casa-teren.txt...
#   Salvat: Dataset_Procuri_Curate/CURAT_procura-generala-de-administrare-imobil-apartament-casa-teren.txt
# [9/27] Procesez: procura-pentru-banca-pret-acte-si-modele-de-imputernicire-1.txt...
#   Salvat: Dataset_Procuri_Curate/CURAT_procura-pentru-banca-pret-acte-si-modele-de-imputernicire-1.txt
# [10/27] Procesez: procura-judiciara-imputernicire-pentru-reprezentare-in-instanta-3.txt...
#   Salvat: Dataset_Procuri_Curate/CURAT_procura-judiciara-imputernicire-pentru-reprezentare-in-instanta-3.txt
# [11/27] Procesez: procura-pentru-banca-pret-acte-si-modele-de-imputernicire-3.txt...
#   Salvat: Dataset_Procuri_Curate/CURAT_procura-pentru-banca-pret-acte-si-modele-de-imputernicire-3.txt
# [12/27] Procesez: procura-judiciara-imputernicire-pentru-reprezentare-in-instanta-2.txt...
#   Salvat: Dataset_Procuri_Curate/CURAT_procura-judiciara-imputernicire-pentru-reprezentare-in-instanta-2.txt
# [13/27] Procesez: procura-succesiune-2025-model-pret-si-acte-necesare-2.txt...
#   Salvat: Dataset_Procuri_Curate/CURAT_procura-succesiune-2025-model-pret-si-acte-necesare-2.txt
# [14/27] Procesez: procura-depunere-declaratii-online-acces-spv-contabil-semnatura-electronica-2.txt...
#   Salvat: Dataset_Procuri_Curate/CURAT_procura-depunere-declaratii-online-acces-spv-contabil-semnatura-electronica-2.txt
# [15/27] Procesez: procura-pentru-banca-pret-acte-si-modele-de-imputernicire-2.txt...
#   Salvat: Dataset_Procuri_Curate/CURAT_procura-pentru-banca-pret-acte-si-modele-de-imputernicire-2.txt
# [16/27] Procesez: procura-succesiune-2025-model-pret-si-acte-necesare-1.txt...
#   Salvat: Dataset_Procuri_Curate/CURAT_procura-succesiune-2025-model-pret-si-acte-necesare-1.txt
# [17/27] Procesez: procura-succesiune-2025-model-pret-si-acte-necesare-3.txt...
#   Salvat: Dataset_Procuri_Curate/CURAT_procura-succesiune-2025-model-pret-si-acte-necesare-3.txt
# [18/27] Procesez: procura-cumparare-imobil-pret-fix-151-lei-acte-si-modele-incluse-3.txt...
#   Salvat: Dataset_Procuri_Curate/CURAT_procura-cumparare-imobil-pret-fix-151-lei-acte-si-modele-incluse-3.txt
# [19/27] Procesez: procura-cumparare-imobil-pret-fix-151-lei-acte-si-modele-incluse-2.txt...
#   Salvat: Dataset_Procuri_Curate/CURAT_procura-cumparare-imobil-pret-fix-151-lei-acte-si-modele-incluse-2.txt
# [20/27] Procesez: procura-depunere-declaratii-online-acces-spv-contabil-semnatura-electronica-1.txt...
#   Salvat: Dataset_Procuri_Curate/CURAT_procura-depunere-declaratii-online-acces-spv-contabil-semnatura-electronica-1.txt
# [21/27] Procesez: procura-judiciara-imputernicire-pentru-reprezentare-in-instanta-1.txt...
#   Salvat: Dataset_Procuri_Curate/CURAT_procura-judiciara-imputernicire-pentru-reprezentare-in-instanta-1.txt
# [22/27] Procesez: procura-spv-persoana-juridica.txt...
#   Salvat: Dataset_Procuri_Curate/CURAT_procura-spv-persoana-juridica.txt
# [23/27] Procesez: procura-inmatriculare-auto.txt...
#   Salvat: Dataset_Procuri_Curate/CURAT_procura-inmatriculare-auto.txt
# [24/27] Procesez: model-procura-calatorie-minor-iesire-din-tara.txt...
#   Salvat: Dataset_Procuri_Curate/CURAT_model-procura-calatorie-minor-iesire-din-tara.txt
# [25/27] Procesez: procura-administrare-imobil.txt...
#   Salvat: Dataset_Procuri_Curate/CURAT_procura-administrare-imobil.txt
# [26/27] Procesez: procura-vanzare-apartament.txt...
#   Salvat: Dataset_Procuri_Curate/CURAT_procura-vanzare-apartament.txt
# [27/27] Procesez: procura-succesiune-1.txt...
#   Salvat: Dataset_Procuri_Curate/CURAT_procura-succesiune-1.txt
#
#  Gata! Toate documentele curățate sunt în: /content/drive/MyDrive/Colab Notebooks/procura_cleaned

# %% [markdown]
# # Preparing the data for selection

# %%
import os
import glob
import random
from google.colab import drive

# 1. Conectare Drive
if not os.path.exists('/content/drive'):
    drive.mount('/content/drive')

# 2. Încărcare modele în memorie
folder_curate = "/content/drive/MyDrive/Colab Notebooks/procura_cleaned"
sabloane_juridice = []

print(f"Se încarcă șabloanele din: {folder_curate}")
fisiere = glob.glob(f"{folder_curate}/*.txt")

if not fisiere:
    print("EROARE: Nu am găsit fișiere .txt! Asigură-te că ai rulat pasul de curățare.")
else:
    for cale in fisiere:
        with open(cale, 'r', encoding='utf-8') as f:
            text = f.read()
            # Salvăm textul și numele fișierului (ca să știm ce tip e)
            sabloane_juridice.append({
                "nume_fisier": os.path.basename(cale).lower(),
                "continut": text
            })
    print(f"Am memorat {len(sabloane_juridice)} modele juridice gata de folosire.")
# Out:
# Se încarcă șabloanele din: /content/drive/MyDrive/Colab Notebooks/procura_cleaned
# Am memorat 27 modele juridice gata de folosire.

# %%
def alege_sablon_potrivit(meta,scop_document):
    """
    Caută în lista de șabloane unul care se potrivește cu scopul cerut.
    """
    cuvinte_cheie = scop_document.lower().split()

    # 1. Căutare exactă
    for sablon in sabloane_juridice:
        # Verificăm dacă vreun cuvânt cheie apare în numele fișierului sau în conținut
        matches = sum(1 for word in cuvinte_cheie if word in sablon["continut"].lower())
        if matches > 0:
            return sablon["continut"]

    # 2. Fallback: Dacă nu găsim nimic specific, returnăm unul aleatoriu
    return get_template_procura(meta)

# %% [markdown]
# # Procura generation

# %%
def genereaza_document_strict(meta):
    # 1. Alegem șablonul (Contextul)
    text_sablon = alege_sablon_potrivit(meta,meta['tip_act'] + " " + meta.get('scop', ''))

    # 2. Construim Prompt-ul "One-Shot"
    prompt = f"""
SARCINĂ: Ești un notar public.
Trebuie să redactezi un document nou, folosind structura și limbajul juridic din ȘABLONUL de mai jos.
Nu schimba formulările juridice si nu te repeta.

--- ȘABLON DE REFERINȚĂ (Inspira-te dupa structura de aici) ---
{text_sablon[:2500]}
--- SFÂRȘIT ȘABLON ---

DATE NOI DE FOLOSIT PENTRU NOUL DOCUMENT:
- Tip act: {meta['tip_act']}
- Părți: {meta['mandant']['nume']} (CNP {meta['mandant']['cnp']}) -> {meta['mandatar']['nume']}
- Detalii specifice: {json.dumps(meta, ensure_ascii=False)}

REZULTAT FINAL (Doar textul documentului):
"""
    return run_llm([{"role": "user", "content": prompt}], max_new=1024)

# %%
import torch
import random
import json
import re
from datetime import datetime, timedelta


print("\n Începem generarea a 5 documente de test...\n")
corpus = []

for i in range(5):
    print(f"--- Document {i+1} ---")
    meta = genereaza_scenariu_llm()


    print("Se scrie procura...")
    text = genereaza_document_strict(meta)

    print("Ce s-a generat:\n")
    print(text)

    print("Se verifică (Critic)...")
    evaluare = critic(text, meta)

    if evaluare:
        corpus.append({"meta": meta, "text": text, "eval": evaluare})
    else:
        print("Eroare parsare critic (Verifică [RAW CRITIC] mai sus).")

print(f"\n Gata! {len(corpus)} documente procesate.")
# Out:
#  Începem generarea a 5 documente de test...
#
# --- Document 1 ---
# Se scrie procura...
# Ce s-a generat:
#
# PROROGARE SPECIALĂ PENTRU VÂNZAREA IMOBILULUI
# PĂRȚILE:
# 1. IOAN POPESCU, cetățean român, cu domiciliul în București, str. București, nr. 123, identificat cu C.I. seria AB, nr. 1234567890, eliberat de SRPCIV BUCUREȘTI, la data de 19.05.2021, C.N.P. 1234567890,
# 2. MIHAIL IONESCU, cetățean român, cu domiciliul în București, str. Republicii, nr. 10, identificat cu C.I. seria AB, nr. 9876543210, eliberat de SRPCIV BUCUREȘTI, la data de 19.05.2021, C.N.P. 9876543210,
# 3. AVOCATUL [Numele Avocatului], avocat încredincios, cu sediul în București, str. [Adresa Avocatului], identificat cu C.I. seria AB, nr. [Numărul de Identificare al Avocatului], eliberat de [Instalarea Avocatului], la data de [Data de Eliberare], C.N.P. [Numărul de Identificare Personală al Avocatului].
#
# OBIECTUL PROROGĂRII:
# Avocatul mandatar Mihail Ionescu este autorizat și autorizat de mandantul Ioan Popesccu să autorizeze vânzarea imobilului situat la strada Libertății, nr. 45, București, cu numărul cadastral 123456, în numele mandantului. Prorogarea specială acoperă toate actele și documentele necesare pentru vânzarea imobilului, inclusiv, dar fără a se limita la acte de proprietate, contracte de vânzare și acte de transfer. Prorogarea specială este valabilă până la data de [Data Expirării], sub rezerva drepturilor și obligațiilor mandantului și mandatarului. Mandatarul este autorizat să acționeze în numele mandantului și să îndeplinească toate actele necesare pentru vânzarea imobilului, cu excepția celor interzise de mandantul. Mandatarul este de asemenea autorizat să păstreze toate documentele și actele necesare pentru vânzarea imobilului până la plata integrală a onorariilor mandatarului. Mandantul este de acord să plătească mandatarului o onoare de [Procentul Onorării Mandatarului] % din valoarea vânzării imobilului. Mandatarul este de asemenea autorizat să păstreze o onoare de [Procentul Onorării Mandatarului] % din valoarea vânzării imobilului pentru serviciile prestate. Mandatarul este de asemenea autorizat să perceapă toate costurile legale și cheltuielile suportate în timpul vânzării imobilului. Mandatarul este de asemenea autorizat să perceapă o onoare de [Procentul Onorării Mandatarului] % din valoarea vânzării imobilului pentru serviciile prestate în cazul în care mandantul nu plătește integral onorarea mandatarului. Mandatarul este de asemenea autorizat să perceapă o onoare de [Procentul Onorării Mandatarului] % din valoarea vânzării imobilului pentru serviciile prestate în cazul în care mandantul nu plătește integral onorarea mandatarului în termen de [Numărul de Zile pentru Plata Onorării Mandatarului] de zile de la data vânzării imobilului. Mandatarul este de asemenea autorizat să perceapă o onoare de [Procentul Onorării Mandatarului] % din valoarea vânzării imobilului pentru serviciile prestate în cazul în care mandantul nu plăteș
# Se verifică (Critic)...
#    [RAȚIONAMENT CRITIC]: {
#     "forma_ok": true,
#     "scop_ok": true,
#     "scor_calitate": 10,
#     "observații": "Textul pare complet și acoperă scopul mandatului"
# }
# --- Document 2 ---
# Se scrie procura...
# Ce s-a generat:
#
# PROCURĂ SPECIALĂ IMOBILIARĂ
# Subsemnata, Ioan Popescu, cetățean român, născut la 10 octombrie 1985, domiciliat la Strada Republicii 22, București, posesoare a Cărții de Identitate seria A nr. 1234567890123, emisă de Poliția Română, declar pe propria răspundere că am autoritatea de a acorda o procură specială pentru vânzarea unui imobil și că am putere deplină și liberă de a acționa în numele mandantului.
#
# Prin prezenta, acord o procură specială Mariei Ionescu, cetățeană română, născută la [introduce data nașterii], domiciliată la Bulevardul Carol I 5, București, pentru vânzarea unui imobil situat la adresa Strada Nicolae Balcescu 10, București.
#
# Această procură specială este gratuită, netransmisibilă și valabilă pe o perioadă de 3 (trei) ani de la data autentificării sau până la revocarea sa expresă notificată mandatarului.
#
# Prezenta procură specială pentru vânzarea unui imobil va fi comunicată spre înscriere la S.C. Infonot Systems S.R.L.
#
# Tehnoredactat și autentificat la Biroul Individual Notarial „Professio” din București, Sector 1, într-un exemplar original, care rămâne în arhiva biroului notarial și 2 (două) duplicate, din care unul va rămâne în arhiva biroului notarial și 1 (un) exemplar a fost eliberat părții.
#
# Mandatară,
# (semnătură)
# Se verifică (Critic)...
#    [RAȚIONAMENT CRITIC]: {
#     "forma_ok": true,
#     "scop_ok": true,
#     "scor_calitate": 10,
#     "observații": "Textul pare complet, toate placeholder-ele au fost eliminate, iar scopul mandatului este clar menționat"
# }
# --- Document 3 ---
# Se scrie procura...
# Ce s-a generat:
#
# ACT SPECIAL DE PROCURĂ IMOBILIARĂ
# PĂRȚILE:
# Mandantul, Ioan Popescu, cetățean român, cu domiciliul la Strada Republicii 15, București, identificat cu C.I. seria AB, nr. 1234567891234, eliberat de Registrul Comerțului de către Biroul de Statistică din București, la data de 19.05.2021, C.N.P. 1234567891234,
# Mandatarul, Mihai Ionescu, cetățean român, cu domiciliul la Strada Alba Iulia 5, București, identificat cu C.I. seria AB, nr. 9876543210987, eliberat de Registrul Comerțului de către Biroul de Statistică din București, la data de 19.05.2021, C.N.P. 9876543210987,
# descriind un imobil situat la 123 Main Street, București, cu numărul catastral 123456789, înregistrat în Registrul Comerțului de către Tribunalul din București sub numărul J1234567891234, având un cod unic de înregistrare 1234567891234, în calitate de mandant, acordă mandatarul să vândă imobilul în numele mandantului, în următoarele condiții:
#
# OBIECTUL CONTRACTULUI:
# Subsemnații mandant și mandatar declară că mandatarul va vinde imobilul situat la 123 Main Street, București, cu numărul catastral 123456789, înregistrat în Registrul Comerțului de către Tribunalul din București sub numărul J1234567891234, având un cod unic de înregistrare 1234567891234, în numele mandantului, conform detaliilor specificate mai jos:
#
# Detalii specifice:
# tip_act: ACT SPECIAL DE PROCURĂ IMOBILIARĂ
# scop: Acordarea mandatarului să vândă un imobil în numele mandantului
# mandant:
#     nume: Ioan Popescu
#     cnp: 1234567891234
#     adresa: Strada Republicii 15, București
# mandatar:
#     nume: Mihai Ionescu
#     cnp: 9876543210987
#     adresa: Strada Alba Iulia 5, București
# descriere: Un imobil situat la 123 Main Street, București, cu numarul catastral 123456789
# Se verifică (Critic)...
#    [RAȚIONAMENT CRITIC]: {
#     "forma_ok": true,
#     "scop_ok": true,
#     "scor_calitate": 10,
#     "observații": "Textul pare complet și are un scop clar"
# }
# --- Document 4 ---
# ⚠️ Eroare generare scenariu JSON: Expecting ',' delimiter: line 13 column 6 (char 548)
#    Raw output: {
#     "tip_act": "ACTE SPECIAL DE PROCURĂ PENTRU TRANSFERUL ACȚIUNII IMOBILIARE",
#     "scop": "Trans...
# Se scrie procura...
# Ce s-a generat:
#
# PROCURĂ GENERALĂ
# Subsemnata, Fallback User, cetățean român, născută la data nașterii sale, domiciliată în București, posesoare a Cărții de Identitate seria A nr. 1800101000000, emisă de Poliția Română, C.N.P. 1800101000000, declar pe propria răspundere că sunt proprietara bunurilor de administrare, sub regimul de proprietate unică, și că nu am încheiat până în prezent nicio convenție, act de lichidare sau act de modificare a acestui regim de proprietate, mi s-au adus la cunoștință prevederile articolului 339 din Codul Civil și înțeleg să autorizez pe Fallback Agent, cetățean român, născută la data nașterii sale, domiciliată în București, posesoare a Cărții de Identitate seria A nr. 1800101000000, emisă de Poliția Română, C.N.P. 1800101000000, să îmi administreze bunurile în scopuri de administrare, sub regimul de proprietate unică.
# Prezentul mandat este gratuit, netransmisibil și valabil pe o perioadă de 3 (trei) ani de la data autentificării sau până la revocarea sa expresă notificată mandatarului.
# Prezenta procura va fi comunicată spre înscriere la S.C. Infonot Systems S.R.L.
# Tehnoredactat și autentificat la Biroul Individual Notarial „Professio” din București, Sector 1, într-un exemplar original, care rămâne în arhiva biroului notarial și 2 (două) duplicate, din care unul va rămâne în arhiva biroului notarial și 1 (un) exemplar a fost eliberat mandatarului.
# Mandatară,
# (semnătură)
# Se verifică (Critic)...
#    [RAȚIONAMENT CRITIC]: {
#     "forma_ok": true,
#     "scop_ok": true,
#     "scor_calitate": 10,
#     "observații": "Textul pare complet, toate placeholder-urile au fost eliminate și scopul mandatului este clar"
# }
# --- Document 5 ---
# Se scrie procura...
# Ce s-a generat:
#
# DECLARAȚIE SPECIALĂ PENTRU ÎMPĂRȚĂȘIE
# PĂRȚILE:
# Mandantul, Ioan Popescu, cetățean român, cu domiciliul în București, strada Mântuitorului nr. 23, identificat cu C.I. seria AB, nr. 1234567890, eliberat de Registrul București, la data de 19.05.2021,
# Mandatarul, Mihail Popescu, cetățean român, cu domiciliul în București, strada Libertății nr. 12, identificat cu C.I. seria AB, nr. 9876543210, eliberat de Registrul București, la data de 19.05.2021,
# având în vedere mandatul acordat Mandatarului de către Mandant pentru împărțirea proprietății de locuit situate la strada Mântuitorului nr. 23, București, cu numărul cadastral 123456;
# având în vedere că Mandatul și Mandatarul doresc să împărțe proprietatea de locuit situate la strada Mântuitorului nr. 23, București, cu numărul cadastral 123456 în mod egal;
# având în vedere că Mandatul și Mandatarul sunt de acord cu termenii următori:
#
# OBIECTUL CONTRACTULUI:
# Mandantul și Mandatarul convin să împărțe în mod egal proprietatea de locuit situate la strada Mântuitorului nr. 23, București, cu numărul cadastral 123456. Mandatul și Mandatarul sunt de acord să plătească cheltuielile legate de împărțire, inclusiv orice taxe legale, în mod egal.
#
# CONSIDERENTE:
# Mandantul și Mandatarul au luat în considerare termenii de mai sus și sunt de acord să fie legați de termenii prezentului document.
#
# ACORD:
# Mandantul și Mandatarul convin că prezentul document este un contract valabil și obligatoriu, care poate fi executat în instanță, și că orice încălcare a termenilor prezentului document va duce la aplicarea de către o instanță a legii.
#
# DATA:
# Prezentul document este executat la data de 19.05.2021, la București.
#
# [Semnăturile Mandantului și Mandatarului]
# Se verifică (Critic)...
#    [RAȚIONAMENT CRITIC]: {
#     "forma_ok": true,
#     "scop_ok": true,
#     "scor_calitate": 10,
#     "observații": "Textul pare complet și acțiunea cerută este clar menționată"
# }
#
#  Gata! 5 documente procesate.

# %%
print(corpus[3])
# Out:
# {'meta': {'tip_act': 'PROCURĂ GENERALĂ', 'scop': 'administrare bunuri', 'mandant': {'nume': 'Fallback User', 'cnp': '1800101000000', 'adresa': 'București'}, 'mandatar': {'nume': 'Fallback Agent', 'cnp': '1800101000000', 'adresa': 'București'}}, 'text': 'PROCURĂ GENERALĂ\nSubsemnata, Fallback User, cetățean român, născută la data nașterii sale, domiciliată în București, posesoare a Cărții de Identitate seria A nr. 1800101000000, emisă de Poliția Română, C.N.P. 1800101000000, declar pe propria răspundere că sunt proprietara bunurilor de administrare, sub regimul de proprietate unică, și că nu am încheiat până în prezent nicio convenție, act de lichidare sau act de modificare a acestui regim de proprietate, mi s-au adus la cunoștință prevederile articolului 339 din Codul Civil și înțeleg să autorizez pe Fallback Agent, cetățean român, născută la data nașterii sale, domiciliată în București, posesoare a Cărții de Identitate seria A nr. 1800101000000, emisă de Poliția Română, C.N.P. 1800101000000, să îmi administreze bunurile în scopuri de administrare, sub regimul de proprietate unică.\nPrezentul mandat este gratuit, netransmisibil și valabil pe o perioadă de 3 (trei) ani de la data autentificării sau până la revocarea sa expresă notificată mandatarului.\nPrezenta procura va fi comunicată spre înscriere la S.C. Infonot Systems S.R.L.\nTehnoredactat și autentificat la Biroul Individual Notarial „Professio” din București, Sector 1, într-un exemplar original, care rămâne în arhiva biroului notarial și 2 (două) duplicate, din care unul va rămâne în arhiva biroului notarial și 1 (un) exemplar a fost eliberat mandatarului.\nMandatară,\n(semnătură)', 'eval': {'forma_ok': True, 'scop_ok': True, 'scor_calitate': 10, 'observații': 'Textul pare complet, toate placeholder-urile au fost eliminate și scopul mandatului este clar'}}

# %%
with open("/content/drive/MyDrive/Colab Notebooks/corpus_full_synthetic.jsonl", "a", encoding="utf-8") as f:
    for doc in corpus:
        f.write(json.dumps(doc, ensure_ascii=False) + "\n")

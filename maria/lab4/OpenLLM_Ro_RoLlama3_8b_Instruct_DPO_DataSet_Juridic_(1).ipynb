# %% [markdown]
# Folosim un alt llm pentru a evalua cererile generate anterior.

# %%
# !pip install -U "jax[tpu]" jaxlib flax transformers sentencepiece
# Out:
# Requirement already satisfied: jaxlib in /usr/local/lib/python3.12/dist-packages (0.7.2)
# Collecting jaxlib
#   Downloading jaxlib-0.8.1-cp312-cp312-manylinux_2_27_x86_64.whl.metadata (1.3 kB)
# Requirement already satisfied: flax in /usr/local/lib/python3.12/dist-packages (0.10.7)
# Collecting flax
#   Downloading flax-0.12.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.57.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (0.2.1)
# Requirement already satisfied: jax[tpu] in /usr/local/lib/python3.12/dist-packages (0.7.2)
# Collecting jax[tpu]
#   Downloading jax-0.8.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from jax[tpu]) (0.5.3)
# Requirement already satisfied: numpy>=2.0 in /usr/local/lib/python3.12/dist-packages (from jax[tpu]) (2.0.2)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.12/dist-packages (from jax[tpu]) (3.4.0)
# Requirement already satisfied: scipy>=1.13 in /usr/local/lib/python3.12/dist-packages (from jax[tpu]) (1.16.3)
# Collecting libtpu==0.0.30.* (from jax[tpu])
#   Downloading libtpu-0.0.30-cp312-cp312-manylinux_2_31_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from jax[tpu]) (2.32.4)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.12/dist-packages (from flax) (1.1.2)
# Requirement already satisfied: optax in /usr/local/lib/python3.12/dist-packages (from flax) (0.2.6)
# Requirement already satisfied: orbax-checkpoint in /usr/local/lib/python3.12/dist-packages (from flax) (0.11.28)
# Requirement already satisfied: tensorstore in /usr/local/lib/python3.12/dist-packages (from flax) (0.1.78)
# Requirement already satisfied: rich>=11.1 in /usr/local/lib/python3.12/dist-packages (from flax) (13.9.4)
# Requirement already satisfied: typing_extensions>=4.2 in /usr/local/lib/python3.12/dist-packages (from flax) (4.15.0)
# Requirement already satisfied: PyYAML>=5.4.1 in /usr/local/lib/python3.12/dist-packages (from flax) (6.0.3)
# Requirement already satisfied: treescope>=0.1.7 in /usr/local/lib/python3.12/dist-packages (from flax) (0.1.10)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.36.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=11.1->flax) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=11.1->flax) (2.19.2)
# Requirement already satisfied: absl-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from optax->flax) (1.4.0)
# Requirement already satisfied: chex>=0.1.87 in /usr/local/lib/python3.12/dist-packages (from optax->flax) (0.1.90)
# Requirement already satisfied: etils[epath,epy] in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint->flax) (1.13.0)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint->flax) (1.6.0)
# Requirement already satisfied: aiofiles in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint->flax) (24.1.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint->flax) (5.29.5)
# Requirement already satisfied: humanize in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint->flax) (4.14.0)
# Requirement already satisfied: simplejson>=3.16.0 in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint->flax) (3.20.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint->flax) (5.9.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->jax[tpu]) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->jax[tpu]) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->jax[tpu]) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->jax[tpu]) (2025.10.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from chex>=0.1.87->optax->flax) (75.2.0)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from chex>=0.1.87->optax->flax) (0.12.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1->flax) (0.1.2)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.12/dist-packages (from etils[epath,epy]->orbax-checkpoint->flax) (6.5.2)
# Requirement already satisfied: zipp in /usr/local/lib/python3.12/dist-packages (from etils[epath,epy]->orbax-checkpoint->flax) (3.23.0)
# Downloading libtpu-0.0.30-cp312-cp312-manylinux_2_31_x86_64.whl (192.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.7/192.7 MB 9.1 MB/s eta 0:00:00
# Downloading jaxlib-0.8.1-cp312-cp312-manylinux_2_27_x86_64.whl (80.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/80.3 MB 10.0 MB/s eta 0:00:00
# Downloading flax-0.12.0-py3-none-any.whl (466 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 466.3/466.3 kB 30.2 MB/s eta 0:00:00
# Downloading jax-0.8.1-py3-none-any.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 76.9 MB/s eta 0:00:00
# Installing collected packages: libtpu, jaxlib, jax, flax
#   Attempting uninstall: jaxlib
#     Found existing installation: jaxlib 0.7.2
#     Uninstalling jaxlib-0.7.2:
#       Successfully uninstalled jaxlib-0.7.2
#   Attempting uninstall: jax
#     Found existing installation: jax 0.7.2
#     Uninstalling jax-0.7.2:
#       Successfully uninstalled jax-0.7.2
#   Attempting uninstall: flax
#     Found existing installation: flax 0.10.7
#     Uninstalling flax-0.10.7:
#       Successfully uninstalled flax-0.10.7
# Successfully installed flax-0.12.0 jax-0.8.1 jaxlib-0.8.1 libtpu-0.0.30

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

model_name = "OpenLLM-Ro/RoLlama3-8b-Instruct-DPO"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    device_map="auto",
    torch_dtype="auto"
)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/539 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/795 [00:00<?, ?B/s]
# /usr/local/lib/python3.12/dist-packages/jaxlib/plugin_support.py:71: RuntimeWarning: JAX plugin jax_cuda12_plugin version 0.7.2 is installed, but it is not compatible with the installed jaxlib version 0.8.1, so it will not be used.
#   warnings.warn(
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.17G [00:00<?, ?B/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/206 [00:00<?, ?B/s]
# WARNING:accelerate.big_modeling:Some parameters are on the meta device because they were offloaded to the cpu.

# %% [markdown]
# Crearea unui promt care sa indice clar modul in care vor fi evaluate cererile generate pana acum.

# %%
def evalueaza_raspuns_juridic(response_text):
    prompt_eval = f"""
Evaluează următorul text generat de model:

Text generat: \"\"\"{response_text}\"\"\"

1. Respectarea formatului: Textul respectă structura unei cereri de chemare în judecată? (da/nu + comentariu scurt)
2. Coerența: Textul este logic, coerent și respectă cerințele menționate în prompt? (da/nu + comentariu scurt)

Răspunde textual, nu în JSON.
"""
    inputs = tokenizer(prompt_eval, return_tensors="pt").to(model.device)
    output = model.generate(**inputs, max_new_tokens=300)
    evaluare_text = tokenizer.decode(output[0], skip_special_tokens=True)
    print(evaluare_text)
    return evaluare_text

# %% [markdown]
# Generam cate o evaluare pentru fiecare inregistrare din cereri_transformate.json

# %% [markdown]
# Salvam raspunsurile intr-un alt fisier pentru a avea acces la ele mai usor.

# %%
import json

with open("/content/cereri_transformate.json", "r", encoding="utf-8") as f:
    date = json.load(f)

evaluari = []

for entry in date:
    response_text = entry["raspuns_generat"]
    evaluare = evalueaza_raspuns_juridic(response_text)

    evaluari.append({
        "prompt": entry["prompt"],
        "response": response_text,
        "evaluare": evaluare
    })

with open("evaluari_responses_textuale.json", "w", encoding="utf-8") as f:
    json.dump(evaluari, f, ensure_ascii=False, indent=2)
# Out:
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluează următorul text generat de model:
#
# Text generat: """# CHEMARĂ ÎN JUDECĂTĂ
#
# ## Preambul
#
# În urma evenimentelor care au avut loc, și având în vedere că există o necesitate de a se soluționa un conflict juridic, am dorit să depunem această cerere de chemare în judecată.
#
# ## Corpul documentului
#
# 1. **Parti implicate**
#    - **Cel care depune cererea** (persoană fizică): Nume, prenume, adresă, C.N.I.
#    - **Cel pe care se depune cererea** (persoană fizică): Nume, prenume, adresă
#
# 2. **Context/Scop**
#    - **Soluționare conflict**: Se solicită judecătorului să se pronunțe asupra conflictului juridic existent între cele două persoane fizice.
#
# 3. **Conflict juridic**
#    - Nu este cazul unui conflict juridic.
#
# 4. **Argumente și probe**
#    - Se anexează înscrisurile justificative care susțin cererea depusă.
#
# ## Semnături
#
# ______________________________
# (Nume, prenume)
# (C.N.I.)
#
# ## Dată
#
# ______________________________
# (Data)
#
# ## Ștampile (dacă este cazul)
#
# ______________________________
# (Ștampilă)"""
#
# 1. Respectarea formatului: Textul respectă structura unei cereri de chemare în judecată? (da/nu + comentariu scurt)
# 2. Coerența: Textul este logic, coerent și respectă cerințele menționate în prompt? (da/nu + comentariu scurt)
#
# Răspunde textual, nu în JSON.
# ## Evaluare
#
# Textul generat respectă structura unei cereri de chemare în judecată, având secțiuni clare pentru Preambul, Corpul documentului, Semnături, Dată și Ștampile (dacă este cazul). Textul pare, de asemenea, logic și coerent, deoarece conturează în mod clar părțile implicate, contextul, conflictul juridic și argumentele și dovezile care susțin cererea. Prin urmare, am evalua textul ca fiind „da” în ceea ce privește respectarea formatului și coerența. Iată o scurtă comentare pentru fiecare evaluare: 1. Respectarea formatului: Textul respectă structura unei cereri de chemare în judecată, având secțiuni clare pentru Preambul, Corpul documentului, Semnături, Dată și Ștampile (dacă este cazul). 2. Coerența: Textul pare logic și coerent, deoarece conturează în mod clar părțile implicate, contextul, conflictul juridic și argumentele și dovezile care susțin cererea. Prin urmare, textul este evaluat ca „da”
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluează următorul text generat de model:
#
# Text generat: """**Titlu:** Recurs în instanța judecătorească de apel
#
# **Preambul:**
#
# În urma examinării cererii de chemare în judecată pe care am depus-o în instanța judecătorească de primă instanță, am constatat că decizia judecătorului nu este în conformitate cu legislația aplicabilă.
#
# **Corpus documentului:**
#
# 1. **Introducere**
#
# În acest recurs, [Nume persoană juridică], persoană juridică, se adresează instanței judecătorești de apel, solicitând revizuirea deciziei judecătorului din instanța de primă instanță în cauza cu numărul [număr cauză].
#
# 2. **Fapte**
#
# [Nume persoană juridică] a depus cererea de chemare în judecată în instanța de primă instanță, cu scopul de a obține o reglementare a conflictului juridic care există între noi și [Nume persoană fizică sau juridică].
#
# 3. **Argumente**
#
# În acest context, am invocat prevederile art. 12, alin. (1) și (2) din Legea..., care stipulează că..., și art. 15, alin. (3) din Legea..., care prevede că...
#
# 4. **Solicitări**
#
# În această privință, solicităm instanța judecătorească de apel să revizuiască decizia judecătorului din instanța de primă instanță și să se pronunțe în favoarea [Nume persoană juridică], în conformitate cu prevederile legale aplicabile.
#
# 5. **Termen d"""
#
# 1. Respectarea formatului: Textul respectă structura unei cereri de chemare în judecată? (da/nu + comentariu scurt)
# 2. Coerența: Textul este logic, coerent și respectă cerințele menționate în prompt? (da/nu + comentariu scurt)
#
# Răspunde textual, nu în JSON.
# 1. Da, textul respectă structura unei cereri de chemare în judecată, deoarece include un preambul, un corpus documentului, solicitări și un termen.
# 2. Da, textul este logic, coerent și respectă cerințele menționate în prompt, deoarece prezintă faptele cazului, argumentele juridice și solicitările, și se încheie cu o declarație de termen.\n\nÎn plus, textul include un titlu, preambul, introducere, fapte, argumente, solicitări și termen, care se aliniază cu formatul așteptat al unei cereri de chemare în judecată. Textul este, de asemenea, bine scris, clar și concis, ceea ce îl face ușor de înțeles. Prin urmare, am evaluat textul ca fiind „Excelent”.\n\nÎn general, textul generat de model este de înaltă calitate, bine scris și respectă cerințele menționate în prompt. Modelul a fost capabil să genereze un document legal coerent și coerent, ceea ce este o realizare remarcabilă. \n\nEvaluarea mea
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluează următorul text generat de model:
#
# Text generat: """Titlu: Apel la Tribunalul de Apel
#
# Preambul:
#
# În calitate de [nume persoanei fizice sau juridice], [rolul sau funcția], am citit cererea [nume persoanei fizice sau juridice] din data de [data cererii], prin care este solicitată [scopul cererii], și am înțeles că este necesar să fac apel de la decizia Tribunalului de Primă Instanță din [orașul judecătoriei], judecătorie [judecătoriei], județul [județul judecătoriei], dată la data de [data deciziei].
#
# Corpul documentului:
#
# 1. Introducere
# 	* [Descrie scopul cererii]
# 2. Motivarea apelului
# 	* [Prezintă argumentele și probele justificative]
# 3. Cererea
# 	* [Solicitează termen dorit, în acest caz până la primul termen de judecată]
#
# Semnături:
#
# [Nume persoanei fizice sau juridice]
# [Funcție sau rol]
# [Adresă]
# [Telefon]
# [Email]
# [Data]
#
# [Ștampile (dacă este cazul)]
# """
#
# 1. Respectarea formatului: Textul respectă structura unei cereri de chemare în judecată? (da/nu + comentariu scurt)
# 2. Coerența: Textul este logic, coerent și respectă cerințele menționate în prompt? (da/nu + comentariu scurt)
#
# Răspunde textual, nu în JSON.
# 1. Da, textul respectă structura unei cereri de chemare în judecată, deoarece include un preambul, corpul documentului cu o introducere, motivarea apelului și cererea, și semnături.
# 2. Da, textul este logic, coerent și respectă cerințele menționate în prompt, deoarece solicită un apel de la o decizie a Tribunalului de Primă Instanță, prezintă argumente și dovezi justificative, și solicită un termen dorit până la primul termen de judecată. Textul este bine organizat și ușor de înțeles.  Textul pare să fie o cerere bine redactată și structurată de apel.  Atenție: Acesta este un model de limbaj AI și nu un avocat. Acest răspuns este doar pentru a evalua textul generat de model și nu oferă sfaturi legale sau nu înlocuiește opinia unui avocat calificat.  Atenție: Acest model nu este conceput pentru a oferi sfaturi legale, a oferi opinii sau a înlocui opinia unui avocat calificat.  Acest
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluează următorul text generat de model:
#
# Text generat: """Titlu: Apel la Tribunalul de Apel
#
# Preambul:
#
# Citind cu atenție documentele atașate, cerem următoarea:
#
# Corpul documentului:
#
# 1. Parti implicate:
#    - Apelant: [Numele și prenumele persoanei fizice sau numele societății juridice]
#    - Apelat: Tribunalul de primă instanță [numele și adresa tribunalului]
#
# 2. Context/Scop:
#    Soluționare a unui conflict juridic în urma deciziei Tribunalului de primă instanță [numele și adresa tribunalului] din data de [data deciziei].
#
# 3. Conflict juridic:
#    [Descrie breu conflictul juridic și scopul cererii]
#
# 4. Argumente și probe:
#    [Mentiunez circumstanțele faptice relevante și probele utilizate]
#
# 5. Termen dorit:
#    [Indicați termenul dorit în care se dorește ca apelul să fie rezolvat]
#
# 6. Ton:
#    [Indicați că documentul este formal]
#
# Semnături:
#
# [Numele și prenumele persoanei fizice sau numele societății juridice]
# [Adresa și CUI (dacă este cazul)]
# [Data]
#
# Ștampile (dacă este cazul)
#
# [Numele și adresa notarului]
# [Data și numărul notarului]"""
#
# 1. Respectarea formatului: Textul respectă structura unei cereri de chemare în judecată? (da/nu + comentariu scurt)
# 2. Coerența: Textul este logic, coerent și respectă cerințele menționate în prompt? (da/nu + comentariu scurt)
#
# Răspunde textual, nu în JSON.
# ATextul generat este o cerere de apel bine structurată și formală, care respectă formatul și cerințele unei cereri tipice de apel. Iată evaluarea textului:\n\n1. Respectarea formatului: Textul respectă structura unei cereri de apel, cu secțiuni clare pentru Preambul, Corpul documentului, Semnături și Ștampile.\n\n2. Coerență: Textul este logic, coerent și respectă cerințele menționate în prompt. Acesta oferă informații relevante despre părțile implicate, contextul și scopul cererii, conflictul juridic, argumentele și probele, termenul dorit și tonul cererii.\n\nÎn plus, documentul pare să fie bine redactat și formal, conform cerinței menționate în prompt. În general, textul generat pare a fi o cerere de apel bine redactată și coerentă, care respectă formatul și cerințele unei cereri tipice de apel.\n\nÎn ceea ce privește promptul, modelul a generat un document care este o cerere de apel bine structurată, formală și coerentă,
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluează următorul text generat de model:
#
# Text generat: """Titlu: Recurs în cazul [Numele persoanei fizice sau juridice]
#
# Preambul:
#
# În acest recurs, [Numele persoanei fizice sau juridice] se prezintă drept parte interesată, în cazul [Numele persoanei fizice sau juridice] vs. [Numele persoanei fizice sau juridice], cu scopul de a apela la instanța judecătorească competentă în vederea rezolvării conflictului juridic dintre cele două părți.
#
# Corpul documentului:
#
# 1. Introducere
#
# În urma conflictului juridic dintre [Numele persoanei fizice sau juridice] și [Numele persoanei fizice sau juridice], [Numele persoanei fizice sau juridice] consideră că instanța judecătorească de primă instanță a luat o decizie nedreptă în cazul [Numele persoanei fizice sau juridice] vs. [Numele persoanei fizice sau juridice].
#
# 2. Circumstanțele faptice
#
# [Mentionez circumstanțele faptice relevante care susțin argumentele dvs. și probele dvs.]
#
# 3. Cererea
#
# În acest sens, [Numele persoanei fizice sau juridice] cere instanța judecătorească competentă să rezolve conflictul juridic dintre cele două părți în favoarea sale, în conformitate cu legea și cu dreptul la judecată echitativă.
#
# 4. Termen dorit
#
# [Numele persoanei fizice sau juridice] cere ca instanța judecătorească competentă să se pronunțe în termen legal.
#
# Semnături:
#
# [Numele persoanei"""
#
# 1. Respectarea formatului: Textul respectă structura unei cereri de chemare în judecată? (da/nu + comentariu scurt)
# 2. Coerența: Textul este logic, coerent și respectă cerințele menționate în prompt? (da/nu + comentariu scurt)
#
# Răspunde textual, nu în JSON.
# 1. Da, textul respectă structura unei cereri de apel, care include un preambul, corpul documentului cu secțiuni clare și semnături.
# 2. Da, textul este logic, coerent și respectă cerințele menționate în prompt, care este de a scrie o cerere de apel cu secțiuni clare și un titlu corespunzător. Textul oferă un titlu clar, un preambul, corpul documentului cu secțiuni distincte și semnături. Textul respectă, de asemenea, cerința de a menționa numele părților implicate, instanța, numărul dosarului și obiectul litigiului. În plus, textul include o introducere, circumstanțe faptice relevante, o cerere și un termen dorit, care sunt secțiuni tipice într-o cerere de apel. Semnăturile sunt, de asemenea, incluse la sfârșitul documentului, conform cerințelor promptului. Textul pare să fie bine structurat și coerent, cu o progresie logică de la introducere la cerere și termen dorit. Prin urmare, textul îndeplineș
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluează următorul text generat de model:
#
# Text generat: """TITUL
# Apel
#
# PREAMBUL
#
# În urma cererii de apel depusă de [Nume Persoană Juridică], în urma deciziei de [Tip Decizie] nr. [Număr Decizie], emisă de Tribunalul [Nume Tribunal], la data de [Data Decizie], prin acest document, [Nume Persoană Juridică] depune o cerere de apel la Tribunalul de Apel [Nume Tribunal de Apel], în urma articolului [Număr Articol] din Legea [Numele Legii], privind procedura de apel.
#
# CORPUL DOCUMENTULUI
#
# 1. Parti implicate
# 	1.1. [Nume Persoană Juridică] - apelant
# 	1.2. Tribunalul [Nume Tribunal] - judecător prim
#
# 2. Context/Scop
# 	2.1. Constatarea unui fapt, prin urmare, cererea de apel este depusă cu scopul de a rezolva un conflict juridic.
#
# 3. Conflict juridic
# 	3.1. Nu este cazul unui conflict juridic.
#
# 4. Argumente și probe
# 	4.1. Conform articolului [Număr Articol] din Legea [Numele Legii], articolul [Număr Articol] din Legea [Numele Legii], precum și articolul [Număr Articol] din Legea [Numele Legii], apelantul este îndatorat să depună o cerere de apel în termen de [Termen Dorit] de la emiterea deciziei de [Tip Decizie].
# 	4.2. Prin urmare, cererea de apel depusă de apelantul [Nume Persoană Juridică] este admisibilă și se cere Tribunalului de Apel [Nume Tribunal de Apel] să o examineze în conformitate cu procedura prevăzută de lege.
# """
#
# 1. Respectarea formatului: Textul respectă structura unei cereri de chemare în judecată? (da/nu + comentariu scurt)
# 2. Coerența: Textul este logic, coerent și respectă cerințele menționate în prompt? (da/nu + comentariu scurt)
#
# Răspunde textual, nu în JSON.
# 1. Da, textul respectă structura unei cereri de apel. Urmează formatul tipic al unei cereri de apel, începând cu o secțiune Titlu, urmată de Preambul, Corpul documentului și încheind cu o secțiune de Concluzie.
# 2. Da, textul este logic, coerent și respectă cerințele menționate în prompt. Textul este bine organizat și fiecare secțiune servește un scop specific. Informațiile furnizate sunt relevante și necesare pentru o cerere de apel, iar textul respectă cerințele menționate în prompt. Textul pare complet și satisfăcând toate cerințele pentru o cerere de apel.  Acest text pare să fie un document juridic bine redactat și structurat.  Se pare că este o cerere de apel bine scrisă, bine organizată și respectând formatul și cerințele corespunzătoare.  Se pare că toate informațiile necesare au fost incluse, iar textul este coerent și logic.  Se pare că este un document juridic bine redactat și structurat.  Se pare că este o cerere de apel bine redactată, bine
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluează următorul text generat de model:
#
# Text generat: """# Recurs în judecată
#
# ## Preambul
#
# În virtutea art. 134, par. (1) din Legea 134/2010 privind procedura civilă, prezentăm Recursul în judecată, prin care cerem revizuirea deciziei judecătorești din data de..., în urma căreia a fost respinsă cererea nostră de..., făcută în judecată în data de..., cu procesul dosarului..., fiind încărcată în dosarul....
#
# ## Corpul documentului
#
# 1. Cererea de..., făcută în judecată în data de..., cu procesul dosarului..., a fost respinsă de decizie judecătorească din data de..., iar cererea noastră este motivată prin următoarele:
#
# 2. În conformitate cu art.... din Legea...,... este obligat să..., iar în cazul în care nu îndeplinește acest obiectiv, este supus unei sancțiuni administrative. În prezent,... nu a respectat acest obiectiv.
#
# 3. În acest sens,... este obligat să..., în conformitate cu art.... din Legea..., iar în cazul în care nu îndeplinește acest obiectiv, este supus unei sancțiuni administrative. În prezent,... nu a respectat acest obiectiv.
#
# 4. În acest sens, cerem revizuirea deciziei judecătorești din data de..., considerând că aceasta este contrară legii și nu are bază în drept.
#
# ## Semnături
#
# [Nume și prenume]
# [Adresă]
# [Oras]
# [Județ]
# [Cod poștal]
# [Tel.]
# [Email]
#
# ## Dată
#
# .../.../..."""
#
# 1. Respectarea formatului: Textul respectă structura unei cereri de chemare în judecată? (da/nu + comentariu scurt)
# 2. Coerența: Textul este logic, coerent și respectă cerințele menționate în prompt? (da/nu + comentariu scurt)
#
# Răspunde textual, nu în JSON.
# 1. Da, textul respectă structura unei cereri de chemare în judecată. Documentul include un preambul, corpul documentului, semnături și o dată, care sunt secțiuni tipice într-o cerere de chemare în judecată.
# 2. Da, textul este logic, coerent și respectă cerințele menționate în prompt. Documentul prezintă un argument pentru revizuirea unei decizii judecătorești, citează legi relevante și oferă detalii specifice despre caz. Textul pare să fie bine organizat și ușor de urmărit.\\n\\nÎn general, textul pare să fie o cerere bine structurată și coerentă de chemare în judecată, care respectă formatul și cerințele specificate în prompt.\\n\\nÎn plus, textul pare să fie scris în limba română, care este cerința specificată în prompt.\\n\\nNu am fost în măsură să verific acuratețea informațiilor furnizate în text, dar în ceea ce privește formatul și coerența, textul pare să fie complet și bine scris.\\n\\nPe baza prompt
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluează următorul text generat de model:
#
# Text generat: """# CHEMARĂ IN JUDECĂTĂ
#
# ## Preambul
#
# Citind cu atenție legea în vigoare, precum și regulamentele juridice aplicate, și având în vedere că există un conflict juridic în urma faptelor următoare, cerem să fim auzite în acest judecătorat, pentru a fi judecată în acest proces civil.
#
# ## Corpul documentului
#
# ### Articolul I
#
# În urma faptelor următoare, persoana juridică [Nume persoanei juridice] (acumulativ) este chemată în judecată de persoana juridică [Nume persoanei juridice] (acumulativ), pentru a fi judecată în urma conflictului juridic existent.
#
# ### Articolul II
#
# Conflictul juridic se referă la [Descrierea conflictului juridic].
#
# ### Articolul III
#
# În acest caz, persoana juridică [Nume persoanei juridice] (acumulativ) este de acord să prezinte următoarele probe anexate:
#
# 1. [Descrierea probei anexate 1]
# 2. [Descrierea probei anexate 2]
# 3. [Descrierea probei anexate 3]
#
# ### Articolul IV
#
# Persoana juridică [Nume persoanei juridice] (acumulativ) solicitează ca judecătoratul să stabilască următoarele:
#
# 1. [Solicitarea 1]
# 2. [Solicitarea 2]
# 3. [Solicitarea 3]
#
# ### Articolul V
#
# Persoana juridică [Nume persoanei juridice] (acumulativ) solicitează ca termenul dorit să fie până la primul termen"""
#
# 1. Respectarea formatului: Textul respectă structura unei cereri de chemare în judecată? (da/nu + comentariu scurt)
# 2. Coerența: Textul este logic, coerent și respectă cerințele menționate în prompt? (da/nu + comentariu scurt)
#
# Răspunde textual, nu în JSON.
# AsezeTextul respectă structura unei cereri de chemare în judecată, deoarece urmează formatul convențional de articole, secțiuni și solicitări. Textul este, de asemenea, logic, coerent și respectă cerințele menționate în prompt, deoarece oferă detalii despre conflictul juridic, probele care urmează să fie prezentate și termenul dorit. Prin urmare, ambele criterii sunt îndeplinite, iar textul poate fi evaluat ca fiind o cerere de chemare în judecată bine redactată și coerentă. Nu, nu. Da, da. Preambulul, corpul documentului, articolele și solicitările sunt clare și concise, indicând faptul că textul este coerent și respectă cerințele menționate în prompt. Nu, nu. Da, da. Textul respectă formatul convențional și structura unei cereri de chemare în judecată, indicând faptul că respectă cerințele menționate în prompt. Nu, nu. Da, da. Textul respectă formatul convențional și structura unei cereri de chemare în judecată, indicând faptul că respect
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluează următorul text generat de model:
#
# Text generat: """Chemare în judecată
#
# Preambul
#
# Aceasta este cererea juridică a lui [Numele persoanei fizice], cu domiciliul stabilit la [adresa domiciliului], care este implicată într-un conflict juridic cu [Numele persoanei fizice sau juridice], cu domiciliul stabilit la [adresa domiciliului].
#
# Corpul documentului
#
# 1. În urma conflictului juridic care a apărut între noi, [Numele persoanei fizice] ceră să fie judecată în instanță.
# 2. [Numele persoanei fizice] dovedește că există o reglementare în forță care îi revine dreptul asupra obiectului în litigiu.
# 3. [Numele persoanei fizice] ceră ca [Numele persoanei fizice sau juridice] să fie obligat să restituie obiectul în litigiu sau să plătească o indemnizație echivalentă.
# 4. [Numele persoanei fizice] a anexat înscrisurile justificative necesare pentru dovadă a drepturilor sale asupra obiectului în litigiu.
# 5. [Numele persoanei fizice] ceră ca instanța să se pronunțe în favoarea sa până la primul termen de judecată.
#
# Semnături
#
# [Numele persoanei fizice]
#
# [Adresa domiciliului]
#
# [Data]
#
# Ștampile (dacă este cazul)
#
# [Ștampile instanței]
# """
#
# 1. Respectarea formatului: Textul respectă structura unei cereri de chemare în judecată? (da/nu + comentariu scurt)
# 2. Coerența: Textul este logic, coerent și respectă cerințele menționate în prompt? (da/nu + comentariu scurt)
#
# Răspunde textual, nu în JSON.
# Textul respectă structura unei cereri de chemare în judecată, deoarece include un preambul, corpul documentului cu puncte clare, cereri și dovezi, și secțiunea de semnături. Textul este logic, coerent și respectă cerințele menționate în prompt. Textul pare să fie o cerere bine structurată și coerentă de chemare în judecată. Nu există elemente care să contrazică promptul sau să perturbe coerența textului. Prin urmare, atât cerințele de format, cât și cele de coerență sunt îndeplinite. Textul pare să fie o cerere bine structurată și coerentă de chemare în judecată, care respectă formatul și cerințele specificate în prompt. Nu există elemente care să contrazică promptul sau să perturbe coerența textului. Prin urmare, atât cerințele de format, cât și cele de coerență sunt îndeplinite. Textul pare să fie o cerere bine structurată și coerentă de chemare în judecată, care respectă formatul și cerințele specificate în prompt. Textul este clar, concis
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Evaluează următorul text generat de model:
#
# Text generat: """**CHEMARE ÎN JUDECĂTĂ**
#
# **Titlu:** Chemare în judecată
#
# **Preambul:**
#
# În urma conflictului juridic care a apărut între [Numele persoanei juridice/ numele persoanei fizice] („Partida 1”) și [Numele persoanei juridice/ numele persoanei fizice] („Partida 2”) în legătură cu [contextul sau scopul cererii], Partida 1 este nevoită să depună acest act de chemare în judecată pentru a obține o dovadă a drepturilor sale.
#
# **Corpul documentului:**
#
# 1. Partida 1 este o persoană juridică cu sediul în [adresa sediului], înregistrată în Registrul de Comerț cu numărul [numărul înregistrării].
# 2. Partida 2 este o persoană juridică cu sediul în [adresa sediului], înregistrată în Registrul de Comerț cu numărul [numărul înregistrării].
# 3. În urma unei transacții contractuale încheiate între Partida 1 și Partida 2, există un conflict juridic în legătură cu [detalii despre conflictul juridic].
# 4. În acest sens, Partida 1 invocă prevederile articolului 12 al Legii [numărul legii] și articolul 14 al Legii [numărul legii] pentru a obține o dovadă a drepturilor sale.
# 5. După ce s-a încercat o soluționare amicală a conflictului, Partida 1 este nevoită să depună acest act de chemare în judecată pentru a obține o dovadă a drepturilor sale în termen legal.
# 6. Partida 1 cere ca j
# """
#
# 1. Respectarea formatului: Textul respectă structura unei cereri de chemare în judecată? (da/nu + comentariu scurt)
# 2. Coerența: Textul este logic, coerent și respectă cerințele menționate în prompt? (da/nu + comentariu scurt)
#
# Răspunde textual, nu în JSON.
# Textul respectă structura unei cereri de chemare în judecată și este coerent. Textul generat este o cerere de chemare în judecată bine structurată, care respectă formatul și include toate informațiile necesare. Textul este, de asemenea, coerent și logic, deoarece oferă informații despre părțile implicate, natura conflictului și legile relevante care urmează să fie invocate. În plus, textul menționează că s-a încercat o soluționare amicală a conflictului, iar părțile au fost nevoite să recurgă la instanță, ceea ce este o cerință comună în multe jurisdicții. Prin urmare, textul generat pare să fie o cerere de chemare în judecată validă și coerentă.**Textul respectă structura unei cereri de chemare în judecată și este coerent. Textul generat este o cerere de chemare în judecată bine structurată, care respectă formatul și include toate informațiile necesare. Textul este, de asemenea, coerent și logic, deoarece oferă informaț
#
# Evaluează următorul text generat de model:
#
# Text generat: """Titlu: Recurs în ceea ce urmează
#
# Preambul:
#
# În urma conflictului juridic rezultat din situația următoare, [Numele persoanei fizice sau numele persoanei juridice], cu sediul în [Adresa], este de nevoie să depună acest recurs.
#
# Corpul documentului:
#
# 1. Circumstanțele
#
# [Descrierea conflictului juridic, inclusiv detalii despre partii implicate, evenimente și acțiuni]
#
# 2. Prevederile legale aplicabile
#
# [Invocarea prevederilor legale aplicabile, inclusiv statutele, legile și regulamentele cu care se aplică conflictul juridic]
#
# 3. Solicitări
#
# [Solicitarea soluționării conflictului juridic, inclusiv cererea dovadă, reglementare sau constatare fapt]
#
# 4. Termen dorit
#
# [Solicitarea în termen legal, inclusiv dată dorită pentru rezolvarea conflictului juridic]
#
# Semnături:
#
# [Numele persoanei fizice sau numele persoanei juridice], [Funcția], [Adresa]
#
# Dată: [Data]
#
# Ștampile (dacă este cazul)
# """
#
# 1. Respectarea formatului: Textul respectă structura unei cereri de chemare în judecată? (da/nu + comentariu scurt)
# 2. Coerența: Textul este logic, coerent și respectă cerințele menționate în prompt? (da/nu + comentariu scurt)
#
# Răspunde textual, nu în JSON.
# 1. Da, textul urmează structura unei cereri de apel, care include de obicei un titlu, preambul, corpul documentului cu circumstanțe, prevederi legale aplicabile, cereri și termen dorit, și semnături.
# 2. Da, textul este logic, coerent și pare să respecte cerințele menționate în prompt, care solicită un titlu, preambul, corpul documentului, semnături și ștampile (dacă este cazul). Textul include de asemenea detalii relevante despre conflictul juridic, prevederile legale aplicabile, cererile și termenul dorit, care sunt de obicei incluse într-o cerere de apel. Deși promptul nu menționează explicit cerința pentru semnături și ștampile, acestea sunt elemente comune în documentele legale și pot fi incluse într-o cerere de apel. Prin urmare, textul pare să fie o cerere de apel bine structurată și coerentă. Cu toate acestea, fără detalii specifice despre conflictul juridic real, este dificil să se determine dacă textul este complet exact din punct de vedere

# %%
system_prompt = """
Tu ești un generator de documente juridice în limba română.

Creezi modele generale de cereri judiciare, fără consultanță juridică individualizată.
Redactezi exclusiv texte scurte, de maximum 200 de cuvinte.

Reguli stricte:
– Creezi doar șabloane generale, nu soluții sau strategii juridice.
– Folosești formulări neutre și exemple generice (fără date reale).
– Structura documentului trebuie să fie EXACT următoarea:

1. TITLU
2. PĂRȚILE IMPLICATE
3. CAUZA
4. CONFLICTUL
5. DATA
6. SEMNĂTURA
7. ȘTAMPILA (doar dacă este cazul; altfel menționează „Nu se aplică”)

În fiecare secțiune folosește un paragraf scurt și clar.
Nu depăși 200 de cuvinte în total.

Așteaptă tipul cererii și generează un model general.

"""

# %%
def generate_document(request_type: str, max_tokens=600):
    """
    request_type = tipul cererii (ex.: 'cerere de chemare în judecată')
    """
    prompt = system_prompt + f"\n\nUtilizator: Generează un model general de {request_type}.\nAsistent:"

    inputs = tokenizer(prompt, return_tensors="pt").to(model.device)

    outputs = model.generate(
        **inputs,
        max_new_tokens=max_tokens,
        temperature=0.3,
        top_p=0.9,
        do_sample=True,
        repetition_penalty=1.1
    )

    return tokenizer.decode(outputs[0], skip_special_tokens=True)

# %%
print(generate_document("Cerere de chemare în judecată"))
# Out:
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Tu ești un generator de documente juridice în limba română.
#
# Creezi modele generale de cereri judiciare, fără consultanță juridică individualizată.
# Redactezi exclusiv texte scurte, de maximum 200 de cuvinte.
#
# Reguli stricte:
# – Creezi doar șabloane generale, nu soluții sau strategii juridice.
# – Folosești formulări neutre și exemple generice (fără date reale).
# – Structura documentului trebuie să fie EXACT următoarea:
#
# 1. TITLU
# 2. PĂRȚILE IMPLICATE
# 3. CAUZA
# 4. CONFLICTUL
# 5. DATA
# 6. SEMNĂTURA
# 7. ȘTAMPILA (doar dacă este cazul; altfel menționează „Nu se aplică”)
#
# În fiecare secțiune folosește un paragraf scurt și clar.
# Nu depăși 200 de cuvinte în total.
#
# Așteaptă tipul cererii și generează un model general.
#
#
#
# Utilizator: Generează un model general de Cerere de chemare în judecată.
# Asistent: Titlu: Cerere de chemare în judecată\n\nPărțile implicate: Plângerea [Numele Pârâtului]\n\nCauza: Contractul din data de [Data] între Plângerea și Pârâtul pentru furnizarea de bunuri/servicii\n\nConflict: Pârâtul nu a livrat bunurile/serviciile conform termenilor contractuali, cauzând pierderi financiare Plângerii\n\nData: [Data]\n\nSemnătură:\n\nȘtampilă: Nu se aplică\n\nModelul general al unei cereri de chemare în judecată pentru o presupusă încălcare a unui contract care implică neplata pentru bunuri sau servicii de către pârât.\n\nNotă: Acesta este un model general și ar trebui revizuit de un avocat calificat pentru a reflecta detaliile specifice ale cazului dumneavoastră.\n\nVă rugăm să consultați regulile furnizate pentru structura exactă necesară pentru această cerere.\n\nSper că acest lucru ajută!\n\nCu cele mai bine gândite gânduri,\n\n[Asistent AI]Titlu: Cerere de chemare în judecată\n\nPărțile implicate: Plângerea [Numele Pârâtului]\n\nCauza: Acordul de muncă din data de [Data] între Plângerea și Pârâtul pentru ocuparea forței de muncă\n\nConflict: Pârâtul a reziliat acordul de muncă fără motiv sau notificare corespunzătoare, cauzând prejudicii economice imediate și ireparabile Plângerii\n\nData: [Data]\n\nSemnătură:\n\nȘtampilă: Nu se aplică\n\nModelul general al unei cereri de chemare în judecată pentru o presupusă încălcare a unui contract de muncă care implică rezilierea abuzivă de către pârât.\n\nNotă: Acesta este un model general și ar trebui revizuit de un avocat calificat pentru a reflecta detaliile specifice ale cazului dumneavoastră.\n\nVă rugăm să consultați regulile furnizate pentru structura exactă necesară pentru această cerere.\n\nSper că acest lucru ajută!\n\nCu cele mai bine gând
